# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("purchase_data.csv")

# %%
df
# Out:
#         User_ID Product_ID Gender    Age  Occupation City_Category  \
# 0       1000001  P00069042      F   0-17        10.0             A
# 1       1000001  P00248942      F   0-17        10.0             A
# 2       1000001  P00087842      F   0-17        10.0             A
# 3       1000001  P00085442      F   0-17        10.0             A
# 4       1000002  P00285442      M    55+        16.0             C
# ...         ...        ...    ...    ...         ...           ...
# 263010  1004473  P00041942      M  36-45         1.0             B
# 263011  1004473  P00115142      M  36-45         1.0             B
# 263012  1004473  P00188442      M  36-45         1.0             B
# 263013  1004473  P00119442      M  36-45         1.0             B
# 263014       10        NaN    NaN    NaN         NaN           NaN
#
#        Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                               2             0.0                 3.0
# ...

# %%
df.shape
# Out:
# (263015, 12)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 263015 entries, 0 to 263014
# Data columns (total 12 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   User_ID                     263015 non-null  int64
#  1   Product_ID                  263014 non-null  object
#  2   Gender                      263014 non-null  object
#  3   Age                         263014 non-null  object
#  4   Occupation                  263014 non-null  float64
#  5   City_Category               263014 non-null  object
#  6   Stay_In_Current_City_Years  263014 non-null  object
#  7   Marital_Status              263014 non-null  float64
#  8   Product_Category_1          263014 non-null  float64
#  9   Product_Category_2          181501 non-null  float64
#  10  Product_Category_3          80582 non-null   float64
#  11  Purchase                    263014 non-null  float64
# dtypes: float64(6), int64(1), object(5)
# ...

# %%
df.describe()
# Out:
#             User_ID     Occupation  Marital_Status  Product_Category_1  \
# count  2.630150e+05  263014.000000   263014.000000       263014.000000
# mean   1.002941e+06       8.083558        0.408685            5.291099
# std    2.593126e+03       6.524052        0.491592            3.745722
# min    1.000000e+01       0.000000        0.000000            1.000000
# 25%    1.001457e+06       2.000000        0.000000            1.000000
# 50%    1.002972e+06       7.000000        0.000000            5.000000
# 75%    1.004335e+06      14.000000        1.000000            8.000000
# max    1.006040e+06      20.000000        1.000000           18.000000
#
#        Product_Category_2  Product_Category_3       Purchase
# count       181501.000000        80582.000000  263014.000000
# mean             9.844756           12.658298    9319.305269
# std              5.086696            4.129156    4970.152966
# min              2.000000            3.000000     185.000000
# ...

# %%
df.describe(include='O') 

### includes columns with OBJECT data (DATA WITH STRING VALUES)
# Out:
#        Product_ID  Gender     Age City_Category Stay_In_Current_City_Years
# count      263014  263014  263014        263014                     263014
# unique       3507       2       7             3                          5
# top     P00265242       M   26-35             B                          1
# freq          846  198488  104912        111124                      92588

# %% [markdown]
# ### NULL VALUES

# %%
df.dropna(inplace = True)

# %%
df.isnull().sum()
# Out:
# User_ID                       0
# Product_ID                    0
# Gender                        0
# Age                           0
# Occupation                    0
# City_Category                 0
# Stay_In_Current_City_Years    0
# Marital_Status                0
# Product_Category_1            0
# Product_Category_2            0
# Product_Category_3            0
# Purchase                      0
# dtype: int64

# %%
df.head()
# Out:
#     User_ID Product_ID Gender    Age  Occupation City_Category  \
# 1   1000001  P00248942      F   0-17        10.0             A
# 6   1000004  P00184942      M  46-50         7.0             B
# 13  1000005  P00145042      M  26-35        20.0             A
# 14  1000006  P00231342      F  51-55         9.0             A
# 16  1000006   P0096642      F  51-55         9.0             A
#
#    Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 1                           2             0.0                 1.0
# 6                           2             1.0                 1.0
# 13                          1             1.0                 1.0
# 14                          1             0.0                 5.0
# 16                          1             0.0                 2.0
#
#     Product_Category_2  Product_Category_3  Purchase
# 1                  6.0                14.0   15200.0
# 6                  8.0                17.0   19215.0
# ...

# %%
df.duplicated().sum()
# Out:
# 0

# %%
# df.drop_duplicates(inplace=True)     ------- to remove duplicates from rows

# %% [markdown]
# ### LABEL ENCODING

# %%
# LABEL ENCODING - perform any statistical analysis on theobject data columns
# by using fit_transform function of Label Encoder Class we will be converting the data into numerical form

# Label encoding: use to convert categorical data  into numerical data

# %%
df.columns
# Out:
# Index(['User_ID', 'Product_ID', 'Gender', 'Age', 'Occupation', 'City_Category',
#        'Stay_In_Current_City_Years', 'Marital_Status', 'Product_Category_1',
#        'Product_Category_2', 'Product_Category_3', 'Purchase'],
#       dtype='object')

# %%
df['Gender'].unique()
# Out:
# array(['F', 'M'], dtype=object)

# %%
df['Gender'].value_counts()
# Out:
# M    62549
# F    18033
# Name: Gender, dtype: int64

# %%
df['Age'].unique()
# Out:
# array(['0-17', '46-50', '26-35', '51-55', '36-45', '18-25', '55+'],
#       dtype=object)

# %%
df['Age'].value_counts()
# Out:
# 26-35    32313
# 36-45    15908
# 18-25    15321
# 46-50     6365
# 51-55     5489
# 55+       2829
# 0-17      2357
# Name: Age, dtype: int64

# %%
df["City_Category"].unique()
# Out:
# array(['A', 'B', 'C'], dtype=object)

# %%
df["City_Category"].value_counts()
# Out:
# B    33548
# C    27043
# A    19991
# Name: City_Category, dtype: int64

# %%
# TO CONVERT OBJECT INTO NUMERICAL

from sklearn.preprocessing import LabelEncoder

# %%
le = LabelEncoder()

# %%
df["Product_ID"] = le.fit_transform(df["Product_ID"])

# %%
df["Gender"] =le.fit_transform(df["Gender"])

df["Age"] =le.fit_transform(df["Age"])

df["City_Category"] =le.fit_transform(df["City_Category"])

df["Stay_In_Current_City_Years"] =le.fit_transform(df["Stay_In_Current_City_Years"])

# %%
df.dtypes
# Out:
# User_ID                         int64
# Product_ID                      int64
# Gender                          int64
# Age                             int32
# Occupation                    float64
# City_Category                   int32
# Stay_In_Current_City_Years      int32
# Marital_Status                float64
# Product_Category_1            float64
# Product_Category_2            float64
# Product_Category_3            float64
# Purchase                      float64
# dtype: object

# %%
df['Gender'].unique()  
# after ENCODING, changes dtypes of gender with M as 0 and F as 1
# Out:
# array([0, 1], dtype=int64)

# %%
df["City_Category"].unique()
# Out:
# array([0, 1, 2])

# %%
df["Stay_In_Current_City_Years"].unique()
# Out:
# array([2, 1, 4, 0, 3])

# %%
df["Age"].unique()

# earlier: array(['0-17', '46-50', '26-35', '51-55', '36-45', '18-25', '55+'],
#      dtype=object)

# 0-17 as 0, 46-50 as 4
# Out:
# array([0, 4, 2, 5, 3, 1, 6])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 80582 entries, 1 to 263011
# Data columns (total 12 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   User_ID                     80582 non-null  int64
#  1   Product_ID                  80582 non-null  int64
#  2   Gender                      80582 non-null  int64
#  3   Age                         80582 non-null  int32
#  4   Occupation                  80582 non-null  float64
#  5   City_Category               80582 non-null  int32
#  6   Stay_In_Current_City_Years  80582 non-null  int32
#  7   Marital_Status              80582 non-null  float64
#  8   Product_Category_1          80582 non-null  float64
#  9   Product_Category_2          80582 non-null  float64
#  10  Product_Category_3          80582 non-null  float64
#  11  Purchase                    80582 non-null  float64
# dtypes: float64(6), int32(3), int64(3)
# memory usage: 7.1 MB

# %%
df.describe()
# Out:
#             User_ID    Product_ID        Gender           Age    Occupation  \
# count  8.058200e+04  80582.000000  80582.000000  80582.000000  80582.000000
# mean   1.002950e+06    229.309585      0.776216      2.451540      8.173426
# std    1.706623e+03    144.593979      0.416782      1.338429      6.487913
# min    1.000001e+06      0.000000      0.000000      0.000000      0.000000
# 25%    1.001470e+06    110.000000      1.000000      2.000000      2.000000
# 50%    1.002996e+06    206.000000      1.000000      2.000000      7.000000
# 75%    1.004326e+06    351.000000      1.000000      3.000000     14.000000
# max    1.006040e+06    524.000000      1.000000      6.000000     20.000000
#
#        City_Category  Stay_In_Current_City_Years  Marital_Status  \
# count   80582.000000                80582.000000    80582.000000
# mean        1.087513                    1.860775        0.401752
# std         0.758965                    1.285501        0.490255
# ...

# %% [markdown]
# ### STATISTICAL ANALYSIS

# %%
## Hypothesis Test --- One Sample and Two Sample test

# %%
## eg. avg men height == avg height women

# %%
## Write down NUll and the Alternate Hypothesis
# Create sub data from the original based on conditions
# Create samples (Random sampling)
# conclude if we have to go with Null or Alternate Hypothesis

# %%
new_data = df.loc[(df["Age"] == 1) & (df["Gender"]==1)]
new_data
# Out:
#         User_ID  Product_ID  Gender  Age  Occupation  City_Category  \
# 98      1000022         487       1    1        15.0              0
# 103     1000022         402       1    1        15.0              0
# 111     1000022         358       1    1        15.0              0
# 127     1000025         332       1    1         4.0              2
# 128     1000025          71       1    1         4.0              2
# ...         ...         ...     ...  ...         ...            ...
# 262758  1004446         180       1    1        18.0              1
# 262759  1004446         394       1    1        18.0              1
# 262760  1004446          23       1    1        18.0              1
# 262764  1004446          75       1    1        18.0              1
# 262952  1004465         209       1    1         4.0              0
#
#         Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 98                               4             0.0                 1.0
# ...

# %%
# t-test

# number of samples nearly 30

sample_size = 1000

# %%
sample= new_data.sample(sample_size)
sample
# Out:
#         User_ID  Product_ID  Gender  Age  Occupation  City_Category  \
# 1258    1000202         383       1    1         4.0              0
# 213794  1003029         178       1    1         4.0              0
# 153237  1005682         246       1    1         0.0              1
# 100795  1003610         171       1    1         6.0              1
# 28991   1004415         411       1    1         0.0              1
# ...         ...         ...     ...  ...         ...            ...
# 71344   1004958         297       1    1         7.0              1
# 55127   1002454         315       1    1         0.0              1
# 13984   1002078          87       1    1         4.0              2
# 184421  1004446         146       1    1        18.0              1
# 223566  1004441         312       1    1         4.0              0
#
#         Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 1258                             3             0.0                 1.0
# ...

# %%
from scipy.stats import ttest_1samp

# %%
T_value, P_value = ttest_1samp(sample,10000)
# Out:
# C:\Users\USER\anaconda3\Lib\site-packages\scipy\stats\_axis_nan_policy.py:527: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   res = hypotest_fun_out(*samples, axis=axis, **kwds)

# %%
P_value
# Out:
# array([0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 2.98543094e-25])

# %%
T_value
# Out:
# array([ 1.85879532e+04, -2.14491562e+03,            -inf,            -inf,
#        -5.35341521e+04, -4.19636069e+05, -2.33977540e+05, -8.04050830e+05,
#        -1.26114758e+05, -6.98977127e+04, -7.46500106e+04,  1.06715365e+01])

# %%
T_value, P_value = ttest_1samp(sample["Purchase"],10000)

# %%
P_value
# Out:
# 2.985430940081508e-25

# %%
if P_value < 0.05:
    print("Alternate Hypothesis: avg purchase made by Men of age 18-25 was not 10000")
else:
    print("Null Hypothesis: avg purchase made by Men of age 18-25 was 10000")
# Out:
# Alternate Hypothesis: avg purchase made by Men of age 18-25 was not 10000

# %%
T_value
# Out:
# 10.671536519488061

# %%
data_men = df.loc[(df["Gender"]==1) & (df["Age"]==1)]
data_women =df.loc[(df["Gender"]==0) & (df["Age"]==1)]

# %%
data_men.shape
# Out:
# (11904, 12)

# %%
data_women.shape
# Out:
# (3417, 12)

# %%
sample_size = 500
data_men_sample = data_men.sample(sample_size)
data_women_sample = data_women.sample(sample_size)

# %%
from scipy.stats import ttest_ind

t_stats, p_value = ttest_ind(data_men_sample["Purchase"], data_women_sample["Purchase"], equ_var = True)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[76], line 3
#       1 from scipy.stats import ttest_ind
# ----> 3 t_stats, p_value = ttest_ind(data_men_sample["Purchase"], data_women_sample["Purchase"], equ_var = True)
#
# TypeError: ttest_ind() got an unexpected keyword argument 'equ_var'

# %%
df.sample(5, random_state=34)
# Out:
#         User_ID  Product_ID  Gender  Age  Occupation  City_Category  \
# 72105   1005083         145       1    2         4.0              1
# 176743  1003377          41       1    2        17.0              2
# 42751   1000587          85       1    2        20.0              1
# 216167  1003403          35       1    3         5.0              2
# 138999  1003499         184       1    2         3.0              0
#
#         Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 72105                            4             1.0                 1.0
# 176743                           1             0.0                 1.0
# 42751                            3             0.0                 5.0
# 216167                           1             0.0                 3.0
# 138999                           2             0.0                 1.0
#
#         Product_Category_2  Product_Category_3  Purchase
# 72105                  2.0                 8.0   11456.0
# ...

# %%
df.sample(5, random_state=0)
# Out:
#         User_ID  Product_ID  Gender  Age  Occupation  City_Category  \
# 113506  1005519         170       1    3        15.0              2
# 6864    1001099         355       1    2        17.0              2
# 112431  1005345         420       0    2        17.0              2
# 104955  1004158           8       0    0        10.0              0
# 37077   1005716         415       1    0        10.0              2
#
#         Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 113506                           3             0.0                 3.0
# 6864                             4             0.0                 1.0
# 112431                           2             1.0                 5.0
# 104955                           1             0.0                 4.0
# 37077                            4             0.0                 2.0
#
#         Product_Category_2  Product_Category_3  Purchase
# 113506                 4.0                12.0   13311.0
# ...

# %%
np.random.seed(23)
np.random.randint(1,100,10)
# Out:
# array([84, 41, 74, 55, 32, 77, 92, 40, 91, 26])

# %%
sns.pairplot(df)

# %% [markdown]
# ## ANOVA

# %%
df.columns
# Out:
# Index(['User_ID', 'Product_ID', 'Gender', 'Age', 'Occupation', 'City_Category',
#        'Stay_In_Current_City_Years', 'Marital_Status', 'Product_Category_1',
#        'Product_Category_2', 'Product_Category_3', 'Purchase'],
#       dtype='object')

# %%
samp1=df["Product_Category_1"]
samp2=df["Product_Category_2"]
samp3=df["Product_Category_3"]

# %%
from scipy
